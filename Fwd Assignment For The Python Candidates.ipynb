# %% [markdown]
# # Assessment-1:
#
# Input_table.csv contains lot number with various runs. we need a output with lot numbers with runs in the column. Attaching both Input and Output File.

# %%
import pandas as pd

# %%
Data_set1 = pd.read_csv("Assignment1_Input_table.csv")
Data_set1.head()
# Out:
#    Entry Order lot_number group  panel analyst  watson_id     assay_date  \
# 0            1   HMN32540     D      2     SDS         13  30/07/20 0:00
# 1            2   HMN32538     D      2     SDS         13  30/07/20 0:00
# 2            3   HMN32549     D      2     SDS         13  30/07/20 0:00
# 3            4   HMN32537     D      2     SDS         13  30/07/20 0:00
# 4            5   HMN32551     D      2     SDS         13  30/07/20 0:00
#
#    Plate Order  Number    Run Comments for Mean Response Without Drug  \
# 0                    1  122.5
# 1                    1  136.5
# 2                    1  142.5
# 3                    1  101.5
# 4                    1  144.5
#
#    with_drug_response Comments for Mean Response With Drug  inhibition_percent
# 0               136.0                                               -11.020408
# 1               155.5                                               -13.919414
# ...

# %%
Data_set2 = pd.read_csv('Assignment1_Output_table.csv')
Data_set2.head()
# Out:
#   Group     Sample  Run 1  Run 2  Run 3  Run 4  Run 5  Run 6
# 0     B  HMN193206   80.5  119.5   99.5  113.0   97.5   79.5
# 1     B  HMN193214   82.0   92.0   80.5   98.0   84.0   76.5
# 2     A  HMN193215   82.5  102.5   76.5  108.5   74.0   77.5
# 3     B  HMN193222   79.0   96.5   75.5  103.5   86.0   79.0
# 4     B  HMN193223   84.5  148.0  106.5  129.5  101.0   85.5

# %%
D1 = Data_set1.iloc[:,[1]]
D1
# Out:
#     lot_number
# 0     HMN32540
# 1     HMN32538
# 2     HMN32549
# 3     HMN32537
# 4     HMN32551
# ..         ...
# 295   HMN32537
# 296   HMN32551
# 297   HMN32545
# 298   HMN32554
# 299   HMN32531
#
# [300 rows x 1 columns]

# %%
D2 = Data_set2.iloc[:,range(2,8)]
D2
# Out:
#     Run 1  Run 2  Run 3  Run 4  Run 5  Run 6
# 0    80.5  119.5   99.5  113.0   97.5   79.5
# 1    82.0   92.0   80.5   98.0   84.0   76.5
# 2    82.5  102.5   76.5  108.5   74.0   77.5
# 3    79.0   96.5   75.5  103.5   86.0   79.0
# 4    84.5  148.0  106.5  129.5  101.0   85.5
# 5    98.0  155.5  109.5  182.5  127.0  112.0
# 6    92.5  140.0  105.0  111.0   99.5   85.0
# 7    72.5   82.5   71.0   77.5   63.5   71.5
# 8   100.5  120.5   68.0  102.5   83.5   95.0
# 9    76.5   98.0   72.0   88.5   68.5   78.0
# 10   95.0  101.5   94.5   93.0   87.0   81.5
# 11   87.5  136.5   88.0   99.5   87.0   85.5
# 12   93.0  122.5  126.0   89.0   86.0   86.5
# 13   90.0  137.0   86.0  107.0   90.0   87.0
# 14   85.5  117.5   91.5   99.0   77.5   86.5
# 15  106.0  151.5  104.5  115.5   96.0   90.0
# 16   89.0  136.5  112.5  115.0   86.5   90.0
# 17   84.5   94.5   82.5   94.0   83.5   86.0
# 18   94.5  142.5  106.0  104.0   84.5   92.5
# 19   90.5  151.0   87.0  118.5   95.5   88.5
# ...

# %%
attach = D2.assign(lot_number=D1)
attach
# Out:
#     Run 1  Run 2  Run 3  Run 4  Run 5  Run 6 lot_number
# 0    80.5  119.5   99.5  113.0   97.5   79.5   HMN32540
# 1    82.0   92.0   80.5   98.0   84.0   76.5   HMN32538
# 2    82.5  102.5   76.5  108.5   74.0   77.5   HMN32549
# 3    79.0   96.5   75.5  103.5   86.0   79.0   HMN32537
# 4    84.5  148.0  106.5  129.5  101.0   85.5   HMN32551
# 5    98.0  155.5  109.5  182.5  127.0  112.0   HMN32545
# 6    92.5  140.0  105.0  111.0   99.5   85.0   HMN32554
# 7    72.5   82.5   71.0   77.5   63.5   71.5   HMN32531
# 8   100.5  120.5   68.0  102.5   83.5   95.0  HMN366249
# 9    76.5   98.0   72.0   88.5   68.5   78.0  HMN366338
# 10   95.0  101.5   94.5   93.0   87.0   81.5  HMN366384
# 11   87.5  136.5   88.0   99.5   87.0   85.5  HMN366342
# 12   93.0  122.5  126.0   89.0   86.0   86.5  HMN366250
# 13   90.0  137.0   86.0  107.0   90.0   87.0  HMN364398
# 14   85.5  117.5   91.5   99.0   77.5   86.5  HMN364358
# 15  106.0  151.5  104.5  115.5   96.0   90.0  HMN364386
# ...

# %% [markdown]
# # Assessment-2:
#
# Word document contains a table which is basically two table that needs to be split and saved in two different csv files. attaching input and output file.

# %%
# !pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=a8407775c2ec8f85874a4ef7e7a171618eb7988d2037748aaea99e40562617de
#   Stored in directory: c:\users\aryan\appdata\local\pip\cache\wheels\83\8b\7c\09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
# Successfully built python-docx
# ...

# %% [markdown]
# # Assignment-3 (Time Series Analysis)
#
# Input File: ( long_data_.csv, dataset_tk.csv )
#
# Content
#
# (Data is in the form of a time series for a period of 17 months beginning from 2nd Jan 2019 till 23rd May 2020.
# Rows are indexed with dates and columns represent states.
# Rows and columns put together, each datapoint reflects the power consumed in Mega Units (MU) by the given state (column) at the given date (row).)
#
#
#
# Write a program with Time Series Analysis to build a prediction model for next 1 Day for Power Consumption for each state.
# if we place the file in our system and run your code without any changes, it should execute and give the output
